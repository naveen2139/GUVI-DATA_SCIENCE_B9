# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('takehome_user_engagement.csv')
df.head()
# Out:
#          time_stamp  user_id  visited
# 0  22-04-2014 03:53        1        1
# 1  15-11-2013 03:45        2        1
# 2  29-11-2013 03:45        2        1
# 3  09-12-2013 03:45        2        1
# 4  25-12-2013 03:45        2        1

# %%
dt = pd.read_csv('takehome_users.csv')
dt.head(20)
# Out:
#     object_id     creation_time               name  \
# 0           1  22-04-2014 03:53     Clausen August
# 1           2  15-11-2013 03:45      Poole Matthew
# 2           3  19-03-2013 23:14  Bottrill Mitchell
# 3           4  21-05-2013 08:09    Clausen Nicklas
# 4           5  17-01-2013 10:14          Raw Grace
# 5           6  17-12-2013 03:37      Cunha Eduardo
# 6           7  16-12-2012 13:24       Sewell Tyler
# 7           8  31-07-2013 05:34  Hamilton Danielle
# 8           9  05-11-2013 04:04         Amsel Paul
# 9          10  16-01-2013 22:08       Santos Carla
# 10         11  26-12-2013 03:55     Paulsen Malthe
# 11         12  17-04-2014 23:48    Mathiesen L�rke
# 12         13  30-03-2014 16:19      Fry Alexander
# 13         14  11-10-2012 16:14        Rivera Bret
# 14         15  16-07-2013 21:33        Theiss Ralf
# 15         16  11-02-2013 10:09         Engel Ren�
# 16         17  09-04-2014 14:39   Reynolds Anthony
# ...

# %%
df.describe()
# Out:
#              user_id   visited
# count  207917.000000  207917.0
# mean     5913.314197       1.0
# std      3394.941674       0.0
# min         1.000000       1.0
# 25%      3087.000000       1.0
# 50%      5682.000000       1.0
# 75%      8944.000000       1.0
# max     12000.000000       1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207917 non-null  object
#  1   user_id     207917 non-null  int64
#  2   visited     207917 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.8+ MB

# %%
dt.describe()
# Out:
#          object_id  last_session_creation_time  opted_in_to_mailing_list  \
# count  12000.00000                8.823000e+03              12000.000000
# mean    6000.50000                1.379279e+09                  0.249500
# std     3464.24595                1.953116e+07                  0.432742
# min        1.00000                1.338452e+09                  0.000000
# 25%     3000.75000                1.363195e+09                  0.000000
# 50%     6000.50000                1.382888e+09                  0.000000
# 75%     9000.25000                1.398443e+09                  0.000000
# max    12000.00000                1.402067e+09                  1.000000
#
#        enabled_for_marketing_drip        org_id  invited_by_user_id
# count                12000.000000  12000.000000         6417.000000
# mean                     0.149333    141.884583         5962.957145
# std                      0.356432    124.056723         3383.761968
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  object
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  8823 non-null   float64
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          6417 non-null   float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 937.6+ KB

# %%
th = df.groupby('user_id').sum()
th
# Out:
#          visited
# user_id
# 1              1
# 2             14
# 3              1
# 4              1
# 5              1
# ...          ...
# 11996          1
# 11997          1
# 11998          1
# 11999          1
# 12000          1
#
# [8823 rows x 1 columns]

# %%
th.max()
# Out:
# visited    606
# dtype: int64

# %%
th.nlargest(606,'visited')
# Out:
#          visited
# user_id
# 3623         606
# 906          600
# 1811         593
# 7590         590
# 8068         585
# ...          ...
# 1485         113
# 3946         113
# 4141         113
# 11559        113
# 1128         112
#
# [606 rows x 1 columns]

# %%
df = df.fillna(0)

# %%
df
# Out:
#               time_stamp  user_id  visited
# 0       22-04-2014 03:53        1        1
# 1       15-11-2013 03:45        2        1
# 2       29-11-2013 03:45        2        1
# 3       09-12-2013 03:45        2        1
# 4       25-12-2013 03:45        2        1
# ...                  ...      ...      ...
# 207912  06-09-2013 06:14    11996        1
# 207913  15-01-2013 18:28    11997        1
# 207914  27-04-2014 12:45    11998        1
# 207915  02-06-2012 11:55    11999        1
# 207916  26-01-2014 08:57    12000        1
#
# [207917 rows x 3 columns]

# %%
xg = dt.fillna(1)

# %%
xg
# Out:
#        object_id     creation_time               name  \
# 0              1  22-04-2014 03:53     Clausen August
# 1              2  15-11-2013 03:45      Poole Matthew
# 2              3  19-03-2013 23:14  Bottrill Mitchell
# 3              4  21-05-2013 08:09    Clausen Nicklas
# 4              5  17-01-2013 10:14          Raw Grace
# ...          ...               ...                ...
# 11995      11996  06-09-2013 06:14       Meier Sophia
# 11996      11997  10-01-2013 18:28      Fisher Amelie
# 11997      11998  27-04-2014 12:45        Haynes Jake
# 11998      11999  31-05-2012 11:55       Faber Annett
# 11999      12000  26-01-2014 08:57         Lima Tha�s
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
for_people_by_invitation = dt.dropna(axis = 0)

# %%
for_people_by_invitation
# Out:
#        object_id     creation_time               name  \
# 0              1  22-04-2014 03:53     Clausen August
# 1              2  15-11-2013 03:45      Poole Matthew
# 2              3  19-03-2013 23:14  Bottrill Mitchell
# 3              4  21-05-2013 08:09    Clausen Nicklas
# 4              5  17-01-2013 10:14          Raw Grace
# ...          ...               ...                ...
# 11980      11981  05-03-2013 01:53          Fry Tyler
# 11981      11982  06-12-2013 14:39      Barajas Maria
# 11989      11990  05-07-2013 21:00          Juhl Aase
# 11995      11996  06-09-2013 06:14       Meier Sophia
# 11997      11998  27-04-2014 12:45        Haynes Jake
#
#                             email creation_source  last_session_creation_time  \
# 0        AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1          MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2      MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# ...

# %%
for_people_by_invitation.count()
# Out:
# object_id                     4776
# creation_time                 4776
# name                          4776
# email                         4776
# creation_source               4776
# last_session_creation_time    4776
# opted_in_to_mailing_list      4776
# enabled_for_marketing_drip    4776
# org_id                        4776
# invited_by_user_id            4776
# dtype: int64

# %% [raw]
# # There are 4776 People who logged in using invited_by_user_id

# %%
finding_number_of_login = df.groupby(['user_id','visited']).sum()

# %%
from pandas import option_context

with option_context('display.max_colwidth', 400):
    display(finding_number_of_login.head())
# Out:
#                                                                                                                                                                                                                                        time_stamp
# user_id visited
# 1       1                                                                                                                                                                                                                        22-04-2014 03:53
# 2       1        15-11-2013 03:4529-11-2013 03:4509-12-2013 03:4525-12-2013 03:4531-12-2013 03:4508-01-2014 03:4503-02-2014 03:4508-02-2014 03:4509-02-2014 03:4513-02-2014 03:4516-02-2014 03:4509-03-2014 03:4513-03-2014 03:4531-03-2014 03:45
# 3       1                                                                                                                                                                                                                        19-03-2013 23:14
# ...

# %%
finding_number_of_login['time_stamp'] = pd.to_datetime(finding_number_of_login['time_stamp'])

# %%
finding_number_of_login['time_stamp'].head(20)
# Out:
# user_id  visited
# 1        1                2014-04-22 03:53:00
# 2        1          2013-11-15 03:45:00-20:14
# 3        1                2013-03-19 23:14:00
# 4        1                2013-05-22 08:09:00
# 5        1                2013-01-22 10:14:00
# 6        1                2013-12-19 03:37:00
# 7        1                2012-12-20 13:24:00
# 10       1          2013-01-16 22:08:00-20:14
# 11       1                2013-12-27 03:55:00
# 13       1                2014-03-30 16:19:00
# 14       1                2012-12-10 16:14:00
# 17       1                2014-12-04 14:39:00
# 19       1          2013-05-25 14:56:00-20:13
# 20       1          2014-11-03 11:46:00-20:14
# 21       1                2013-01-22 12:27:00
# 22       1                2014-10-02 06:00:00
# 23       1                2012-08-18 08:30:00
# 24       1                2013-09-09 22:20:00
# 25       1          2014-02-25 00:11:00-20:14
# 27       1                2014-01-15 17:35:00
# ...

# %%
finding_number_of_login['time_stamp'].describe()
# Out:
# count                          8823
# unique                         8805
# top       2012-12-06 13:46:00-20:12
# freq                              3
# Name: time_stamp, dtype: object

# %%
finding_number_of_login.describe()
# Out:
#                        time_stamp
# count                        8823
# unique                       8805
# top     2012-12-06 13:46:00-20:12
# freq                            3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
figure(figsize=(15, 5), dpi=80)
sns.countplot(xg['creation_source'])
# Out:
# C:\Users\Harshit Panchal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='creation_source', ylabel='count'>

# %%
sns.countplot(xg['opted_in_to_mailing_list'])
# Out:
# C:\Users\Harshit Panchal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='opted_in_to_mailing_list', ylabel='count'>

# %%
sns.countplot(xg['enabled_for_marketing_drip'])
# Out:
# C:\Users\Harshit Panchal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='enabled_for_marketing_drip', ylabel='count'>

# %%
sns.distplot(xg['opted_in_to_mailing_list'])
# Out:
# <AxesSubplot:xlabel='opted_in_to_mailing_list', ylabel='Density'>

# %%
dups_count = df.pivot_table(columns=['user_id','time_stamp'], aggfunc = 'size')

# %%
dups_count
# Out:
# user_id  time_stamp
# 1        22-04-2014 03:53    1
# 2        03-02-2014 03:45    1
#          08-01-2014 03:45    1
#          08-02-2014 03:45    1
#          09-02-2014 03:45    1
#                             ..
# 11996    06-09-2013 06:14    1
# 11997    15-01-2013 18:28    1
# 11998    27-04-2014 12:45    1
# 11999    02-06-2012 11:55    1
# 12000    26-01-2014 08:57    1
# Length: 207917, dtype: int64

# %%
dups_count1 = df.pivot_table(columns=['user_id'], aggfunc = 'size')

# %%
value_count = dups_count1.sort_values(ascending = False)

# %%
dups_count1.count()
# Out:
# 8823

# %%
dups_count1.describe()
# Out:
# count    8823.000000
# mean       23.565341
# std        73.988152
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max       606.000000
# dtype: float64

# %%
value_count.head(30)
# Out:
# user_id
# 3623     606
# 906      600
# 1811     593
# 7590     590
# 8068     585
# 9402     581
# 4022     580
# 3269     566
# 9312     547
# 7210     545
# 8029     541
# 2474     538
# 2658     526
# 8280     521
# 69       521
# 5297     520
# 4019     519
# 9083     517
# 2519     511
# 4263     509
# 3226     502
# 10599    501
# 6312     500
# 10953    499
# 2316     496
# 8426     496
# 603      489
# 2078     488
# 445      487
# 7536     487
# dtype: int64

# %%
from matplotlib.pyplot import figure
figure(figsize=(60, 12), dpi=200)
plt.eventplot(value_count)

# %%
figure(figsize=(15, 5), dpi=100)
sns.distplot(value_count)
# Out:
# C:\Users\Harshit Panchal\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
for_people_by_invitation.groupby(['creation_source']).sum()
# Out:
#                  object_id  last_session_creation_time  \
# creation_source
# GUEST_INVITE       9544810                2.191292e+12
# ORG_INVITE        19120317                4.396568e+12
#
#                  opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# creation_source
# GUEST_INVITE                          393                         232  227050
# ORG_INVITE                            825                         499  445015
#
#                  invited_by_user_id
# creation_source
# GUEST_INVITE              9410448.0
# ORG_INVITE               19152398.0

# %%
xg.groupby(['creation_source']).sum()
# Out:
#                     object_id  last_session_creation_time  \
# creation_source
# GUEST_INVITE         12868683                2.191292e+12
# ORG_INVITE           25446830                4.396568e+12
# PERSONAL_PROJECTS    12613915                1.053835e+12
# SIGNUP               12565465                2.617436e+12
# SIGNUP_GOOGLE_AUTH    8511107                1.910250e+12
#
#                     opted_in_to_mailing_list  enabled_for_marketing_drip  \
# creation_source
# GUEST_INVITE                             541                         319
# ORG_INVITE                              1078                         644
# PERSONAL_PROJECTS                        512                         303
# SIGNUP                                   525                         319
# SIGNUP_GOOGLE_AUTH                       338                         207
#
#                     org_id  invited_by_user_id
# creation_source
# GUEST_INVITE        305726          12788848.0
# ...
